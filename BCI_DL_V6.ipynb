# %%
import csv
import numpy as np
import torch 
import os
import pandas as pd

# %%
from scipy.signal import butter, sosfilt, sosfreqz

def bandpass_design(start_freq,end_freq,samp_freq,order):
    nqs_freq = samp_freq * 0.5
    low = start_freq / nqs_freq
    high = end_freq / nqs_freq
    sos = butter(order, [low,high], analog = False, btype = 'band',output = 'sos')
    return sos

def bandpass_filter(signal):
    sos = bandpass_design(1,40,200,order = 4)
    output = sosfilt(sos,signal)
    return output

# %%
import glob

# %%
raw_data_folder = r"C:\Users\Admin\Adway"
filenames = []
allfiles = os.listdir(raw_data_folder)
os.chdir(raw_data_folder)
for file in glob.glob("Data_S*.csv"):
    filenames.append(file)

# %%
li = []
columns_name= []
data_agg = []

data_final = []
        
for filename in filenames:
    with open(filename,'r') as f: 
        trials_sampled = int(1.25*128)
        downsampled_data_final = np.empty([5440,1,trials_sampled,56], dtype = 'float')
        
        i,i2 = int(filename[6]+filename[7]), int(filename[14])
        print('Working on {} file ......'.format(filename))
        
        
        columns_name = pd.read_csv(filename, nrows=1).columns.tolist()
        data = pd.read_csv(filename)
        data_copy = data.values
        
        print("Filtering signals with Bandpass IIR Filter!")
        signals = data.iloc[:,1:57]
        signals = bandpass_filter(signals.values)
        
        
        Eventlist = []
        for index, value in enumerate(data_copy[:,58]):
            if value == 1:
                Eventlist.append(index)
       
        print("Slicing the data! We take 250 timepoints post feedback occurence to the user....")
        data_split = []
        for index_2, fb_event in enumerate(Eventlist):
            
            data_split_new = np.reshape(np.transpose(signals[fb_event:fb_event+250,:]),(1,1,250,56))
            data_final.append(data_split_new)
        
        print("The file contains {} feedbacks!".format(len(Eventlist)))
        print("Recording the events, total events saved are : {} \n".format(len(data_final)))
# Out:
# Working on Data_S02_Sess01.csv file ......
# Filtering signals with Bandpass IIR Filter!
# Slicing the data! We take 250 timepoints post feedback occurence to the user....
# The file contains 60 feedbacks!
# Recording the events, total events saved are : 60
#
# Working on Data_S02_Sess02.csv file ......
# Filtering signals with Bandpass IIR Filter!
# Slicing the data! We take 250 timepoints post feedback occurence to the user....
# The file contains 60 feedbacks!
# Recording the events, total events saved are : 120
#
# Working on Data_S02_Sess03.csv file ......
# Filtering signals with Bandpass IIR Filter!
# Slicing the data! We take 250 timepoints post feedback occurence to the user....
# The file contains 60 feedbacks!
# Recording the events, total events saved are : 180
#
# Working on Data_S02_Sess04.csv file ......
# Filtering signals with Bandpass IIR Filter!
# Slicing the data! We take 250 timepoints post feedback occurence to the user....
# The file contains 60 feedbacks!
# Recording the events, total events saved are : 240
#
# Working on Data_S02_Sess05.csv file ......
# Filtering signals with Bandpass IIR Filter!
# Slicing the data! We take 250 timepoints post feedback occurence to the user....
# The file contains 100 feedbacks!
# Recording the events, total events saved are : 340
#
# Working on Data_S06_Sess01.csv file ......
# Filtering signals with Bandpass IIR Filter!
# Slicing the data! We take 250 timepoints post feedback occurence to the user....
# The file contains 60 feedbacks!
# Recording the events, total events saved are : 400
#
# Working on Data_S06_Sess02.csv file ......
# Filtering signals with Bandpass IIR Filter!
# Slicing the data! We take 250 timepoints post feedback occurence to the user....
# The file contains 60 feedbacks!
# Recording the events, total events saved are : 460
#
# Working on Data_S06_Sess03.csv file ......
# Filtering signals with Bandpass IIR Filter!
# Slicing the data! We take 250 timepoints post feedback occurence to the user....
# The file contains 60 feedbacks!
# Recording the events, total events saved are : 520
#
# Working on Data_S06_Sess04.csv file ......
# Filtering signals with Bandpass IIR Filter!
# Slicing the data! We take 250 timepoints post feedback occurence to the user....
# The file contains 60 feedbacks!
# Recording the events, total events saved are : 580
#
# Working on Data_S06_Sess05.csv file ......
# Filtering signals with Bandpass IIR Filter!
# Slicing the data! We take 250 timepoints post feedback occurence to the user....
# The file contains 100 feedbacks!
# Recording the events, total events saved are : 680
#
# Working on Data_S07_Sess01.csv file ......
# Filtering signals with Bandpass IIR Filter!
# Slicing the data! We take 250 timepoints post feedback occurence to the user....
# The file contains 60 feedbacks!
# Recording the events, total events saved are : 740
#
# Working on Data_S07_Sess02.csv file ......
# Filtering signals with Bandpass IIR Filter!
# Slicing the data! We take 250 timepoints post feedback occurence to the user....
# The file contains 60 feedbacks!
# Recording the events, total events saved are : 800
#
# Working on Data_S07_Sess03.csv file ......
# Filtering signals with Bandpass IIR Filter!
# Slicing the data! We take 250 timepoints post feedback occurence to the user....
# The file contains 60 feedbacks!
# Recording the events, total events saved are : 860
#
# Working on Data_S07_Sess04.csv file ......
# Filtering signals with Bandpass IIR Filter!
# Slicing the data! We take 250 timepoints post feedback occurence to the user....
# The file contains 60 feedbacks!
# Recording the events, total events saved are : 920
#
# Working on Data_S07_Sess05.csv file ......
# Filtering signals with Bandpass IIR Filter!
# Slicing the data! We take 250 timepoints post feedback occurence to the user....
# The file contains 100 feedbacks!
# Recording the events, total events saved are : 1020
#
# Working on Data_S11_Sess01.csv file ......
# Filtering signals with Bandpass IIR Filter!
# Slicing the data! We take 250 timepoints post feedback occurence to the user....
# The file contains 60 feedbacks!
# Recording the events, total events saved are : 1080
#
# Working on Data_S11_Sess02.csv file ......
# Filtering signals with Bandpass IIR Filter!
# Slicing the data! We take 250 timepoints post feedback occurence to the user....
# The file contains 60 feedbacks!
# Recording the events, total events saved are : 1140
#
# Working on Data_S11_Sess03.csv file ......
# Filtering signals with Bandpass IIR Filter!
# Slicing the data! We take 250 timepoints post feedback occurence to the user....
# The file contains 60 feedbacks!
# Recording the events, total events saved are : 1200
#
# Working on Data_S11_Sess04.csv file ......
# Filtering signals with Bandpass IIR Filter!
# Slicing the data! We take 250 timepoints post feedback occurence to the user....
# The file contains 60 feedbacks!
# Recording the events, total events saved are : 1260
#
# Working on Data_S11_Sess05.csv file ......
# Filtering signals with Bandpass IIR Filter!
# Slicing the data! We take 250 timepoints post feedback occurence to the user....
# The file contains 100 feedbacks!
# Recording the events, total events saved are : 1360
#
# Working on Data_S12_Sess01.csv file ......
# Filtering signals with Bandpass IIR Filter!
# Slicing the data! We take 250 timepoints post feedback occurence to the user....
# The file contains 60 feedbacks!
# Recording the events, total events saved are : 1420
#
# Working on Data_S12_Sess02.csv file ......
# Filtering signals with Bandpass IIR Filter!
# Slicing the data! We take 250 timepoints post feedback occurence to the user....
# The file contains 60 feedbacks!
# Recording the events, total events saved are : 1480
#
# Working on Data_S12_Sess03.csv file ......
# Filtering signals with Bandpass IIR Filter!
# Slicing the data! We take 250 timepoints post feedback occurence to the user....
# The file contains 60 feedbacks!
# Recording the events, total events saved are : 1540
#
# Working on Data_S12_Sess04.csv file ......
# Filtering signals with Bandpass IIR Filter!
# Slicing the data! We take 250 timepoints post feedback occurence to the user....
# The file contains 60 feedbacks!
# Recording the events, total events saved are : 1600
#
# Working on Data_S12_Sess05.csv file ......
# Filtering signals with Bandpass IIR Filter!
# Slicing the data! We take 250 timepoints post feedback occurence to the user....
# The file contains 100 feedbacks!
# Recording the events, total events saved are : 1700
#
# Working on Data_S13_Sess01.csv file ......
# Filtering signals with Bandpass IIR Filter!
# Slicing the data! We take 250 timepoints post feedback occurence to the user....
# The file contains 60 feedbacks!
# Recording the events, total events saved are : 1760
#
# Working on Data_S13_Sess02.csv file ......
# Filtering signals with Bandpass IIR Filter!
# Slicing the data! We take 250 timepoints post feedback occurence to the user....
# The file contains 60 feedbacks!
# Recording the events, total events saved are : 1820
#
# Working on Data_S13_Sess03.csv file ......
# Filtering signals with Bandpass IIR Filter!
# Slicing the data! We take 250 timepoints post feedback occurence to the user....
# The file contains 60 feedbacks!
# Recording the events, total events saved are : 1880
#
# Working on Data_S13_Sess04.csv file ......
# Filtering signals with Bandpass IIR Filter!
# Slicing the data! We take 250 timepoints post feedback occurence to the user....
# The file contains 60 feedbacks!
# Recording the events, total events saved are : 1940
#
# Working on Data_S13_Sess05.csv file ......
# Filtering signals with Bandpass IIR Filter!
# Slicing the data! We take 250 timepoints post feedback occurence to the user....
# The file contains 100 feedbacks!
# Recording the events, total events saved are : 2040
#
# Working on Data_S14_Sess01.csv file ......
# Filtering signals with Bandpass IIR Filter!
# Slicing the data! We take 250 timepoints post feedback occurence to the user....
# The file contains 60 feedbacks!
# Recording the events, total events saved are : 2100
#
# Working on Data_S14_Sess02.csv file ......
# Filtering signals with Bandpass IIR Filter!
# Slicing the data! We take 250 timepoints post feedback occurence to the user....
# The file contains 60 feedbacks!
# Recording the events, total events saved are : 2160
#
# Working on Data_S14_Sess03.csv file ......
# Filtering signals with Bandpass IIR Filter!
# Slicing the data! We take 250 timepoints post feedback occurence to the user....
# The file contains 60 feedbacks!
# Recording the events, total events saved are : 2220
#
# Working on Data_S14_Sess04.csv file ......
# Filtering signals with Bandpass IIR Filter!
# Slicing the data! We take 250 timepoints post feedback occurence to the user....
# The file contains 60 feedbacks!
# Recording the events, total events saved are : 2280
#
# Working on Data_S14_Sess05.csv file ......
# Filtering signals with Bandpass IIR Filter!
# Slicing the data! We take 250 timepoints post feedback occurence to the user....
# The file contains 100 feedbacks!
# Recording the events, total events saved are : 2380
#
# Working on Data_S16_Sess01.csv file ......
# Filtering signals with Bandpass IIR Filter!
# Slicing the data! We take 250 timepoints post feedback occurence to the user....
# The file contains 60 feedbacks!
# Recording the events, total events saved are : 2440
#
# Working on Data_S16_Sess02.csv file ......
# Filtering signals with Bandpass IIR Filter!
# Slicing the data! We take 250 timepoints post feedback occurence to the user....
# The file contains 60 feedbacks!
# Recording the events, total events saved are : 2500
#
# Working on Data_S16_Sess03.csv file ......
# Filtering signals with Bandpass IIR Filter!
# Slicing the data! We take 250 timepoints post feedback occurence to the user....
# The file contains 60 feedbacks!
# Recording the events, total events saved are : 2560
#
# Working on Data_S16_Sess04.csv file ......
# Filtering signals with Bandpass IIR Filter!
# Slicing the data! We take 250 timepoints post feedback occurence to the user....
# The file contains 60 feedbacks!
# Recording the events, total events saved are : 2620
#
# Working on Data_S16_Sess05.csv file ......
# Filtering signals with Bandpass IIR Filter!
# Slicing the data! We take 250 timepoints post feedback occurence to the user....
# The file contains 100 feedbacks!
# Recording the events, total events saved are : 2720
#
# Working on Data_S17_Sess01.csv file ......
# Filtering signals with Bandpass IIR Filter!
# Slicing the data! We take 250 timepoints post feedback occurence to the user....
# The file contains 60 feedbacks!
# Recording the events, total events saved are : 2780
#
# Working on Data_S17_Sess02.csv file ......
# Filtering signals with Bandpass IIR Filter!
# Slicing the data! We take 250 timepoints post feedback occurence to the user....
# The file contains 60 feedbacks!
# Recording the events, total events saved are : 2840
#
# Working on Data_S17_Sess03.csv file ......
# Filtering signals with Bandpass IIR Filter!
# Slicing the data! We take 250 timepoints post feedback occurence to the user....
# The file contains 60 feedbacks!
# Recording the events, total events saved are : 2900
#
# Working on Data_S17_Sess04.csv file ......
# Filtering signals with Bandpass IIR Filter!
# Slicing the data! We take 250 timepoints post feedback occurence to the user....
# The file contains 60 feedbacks!
# Recording the events, total events saved are : 2960
#
# Working on Data_S17_Sess05.csv file ......
# Filtering signals with Bandpass IIR Filter!
# Slicing the data! We take 250 timepoints post feedback occurence to the user....
# The file contains 100 feedbacks!
# Recording the events, total events saved are : 3060
#
# Working on Data_S18_Sess01.csv file ......
# Filtering signals with Bandpass IIR Filter!
# Slicing the data! We take 250 timepoints post feedback occurence to the user....
# The file contains 60 feedbacks!
# Recording the events, total events saved are : 3120
#
# Working on Data_S18_Sess02.csv file ......
# Filtering signals with Bandpass IIR Filter!
# Slicing the data! We take 250 timepoints post feedback occurence to the user....
# The file contains 60 feedbacks!
# Recording the events, total events saved are : 3180
#
# Working on Data_S18_Sess03.csv file ......
# Filtering signals with Bandpass IIR Filter!
# Slicing the data! We take 250 timepoints post feedback occurence to the user....
# The file contains 60 feedbacks!
# Recording the events, total events saved are : 3240
#
# Working on Data_S18_Sess04.csv file ......
# Filtering signals with Bandpass IIR Filter!
# Slicing the data! We take 250 timepoints post feedback occurence to the user....
# The file contains 60 feedbacks!
# Recording the events, total events saved are : 3300
#
# Working on Data_S18_Sess05.csv file ......
# Filtering signals with Bandpass IIR Filter!
# Slicing the data! We take 250 timepoints post feedback occurence to the user....
# The file contains 100 feedbacks!
# Recording the events, total events saved are : 3400
#
# Working on Data_S20_Sess01.csv file ......
# Filtering signals with Bandpass IIR Filter!
# Slicing the data! We take 250 timepoints post feedback occurence to the user....
# The file contains 60 feedbacks!
# Recording the events, total events saved are : 3460
#
# Working on Data_S20_Sess02.csv file ......
# Filtering signals with Bandpass IIR Filter!
# Slicing the data! We take 250 timepoints post feedback occurence to the user....
# The file contains 60 feedbacks!
# Recording the events, total events saved are : 3520
#
# Working on Data_S20_Sess03.csv file ......
# Filtering signals with Bandpass IIR Filter!
# Slicing the data! We take 250 timepoints post feedback occurence to the user....
# The file contains 60 feedbacks!
# Recording the events, total events saved are : 3580
#
# Working on Data_S20_Sess04.csv file ......
# Filtering signals with Bandpass IIR Filter!
# Slicing the data! We take 250 timepoints post feedback occurence to the user....
# The file contains 60 feedbacks!
# Recording the events, total events saved are : 3640
#
# Working on Data_S20_Sess05.csv file ......
# Filtering signals with Bandpass IIR Filter!
# Slicing the data! We take 250 timepoints post feedback occurence to the user....
# The file contains 100 feedbacks!
# Recording the events, total events saved are : 3740
#
# Working on Data_S21_Sess01.csv file ......
# Filtering signals with Bandpass IIR Filter!
# Slicing the data! We take 250 timepoints post feedback occurence to the user....
# The file contains 60 feedbacks!
# Recording the events, total events saved are : 3800
#
# Working on Data_S21_Sess02.csv file ......
# Filtering signals with Bandpass IIR Filter!
# Slicing the data! We take 250 timepoints post feedback occurence to the user....
# The file contains 60 feedbacks!
# Recording the events, total events saved are : 3860
#
# Working on Data_S21_Sess03.csv file ......
# Filtering signals with Bandpass IIR Filter!
# Slicing the data! We take 250 timepoints post feedback occurence to the user....
# The file contains 60 feedbacks!
# Recording the events, total events saved are : 3920
#
# Working on Data_S21_Sess04.csv file ......
# Filtering signals with Bandpass IIR Filter!
# Slicing the data! We take 250 timepoints post feedback occurence to the user....
# The file contains 60 feedbacks!
# Recording the events, total events saved are : 3980
#
# Working on Data_S21_Sess05.csv file ......
# Filtering signals with Bandpass IIR Filter!
# Slicing the data! We take 250 timepoints post feedback occurence to the user....
# The file contains 100 feedbacks!
# Recording the events, total events saved are : 4080
#
# Working on Data_S22_Sess01.csv file ......
# Filtering signals with Bandpass IIR Filter!
# Slicing the data! We take 250 timepoints post feedback occurence to the user....
# The file contains 60 feedbacks!
# Recording the events, total events saved are : 4140
#
# Working on Data_S22_Sess02.csv file ......
# Filtering signals with Bandpass IIR Filter!
# Slicing the data! We take 250 timepoints post feedback occurence to the user....
# The file contains 60 feedbacks!
# Recording the events, total events saved are : 4200
#
# Working on Data_S22_Sess03.csv file ......
# Filtering signals with Bandpass IIR Filter!
# Slicing the data! We take 250 timepoints post feedback occurence to the user....
# The file contains 60 feedbacks!
# Recording the events, total events saved are : 4260
#
# Working on Data_S22_Sess04.csv file ......
# Filtering signals with Bandpass IIR Filter!
# Slicing the data! We take 250 timepoints post feedback occurence to the user....
# The file contains 60 feedbacks!
# Recording the events, total events saved are : 4320
#
# Working on Data_S22_Sess05.csv file ......
# Filtering signals with Bandpass IIR Filter!
# Slicing the data! We take 250 timepoints post feedback occurence to the user....
# The file contains 100 feedbacks!
# Recording the events, total events saved are : 4420
#
# Working on Data_S23_Sess01.csv file ......
# Filtering signals with Bandpass IIR Filter!
# Slicing the data! We take 250 timepoints post feedback occurence to the user....
# The file contains 60 feedbacks!
# Recording the events, total events saved are : 4480
#
# Working on Data_S23_Sess02.csv file ......
# Filtering signals with Bandpass IIR Filter!
# Slicing the data! We take 250 timepoints post feedback occurence to the user....
# The file contains 60 feedbacks!
# Recording the events, total events saved are : 4540
#
# Working on Data_S23_Sess03.csv file ......
# Filtering signals with Bandpass IIR Filter!
# Slicing the data! We take 250 timepoints post feedback occurence to the user....
# The file contains 60 feedbacks!
# Recording the events, total events saved are : 4600
#
# Working on Data_S23_Sess04.csv file ......
# Filtering signals with Bandpass IIR Filter!
# Slicing the data! We take 250 timepoints post feedback occurence to the user....
# The file contains 60 feedbacks!
# Recording the events, total events saved are : 4660
#
# Working on Data_S23_Sess05.csv file ......
# Filtering signals with Bandpass IIR Filter!
# Slicing the data! We take 250 timepoints post feedback occurence to the user....
# The file contains 100 feedbacks!
# Recording the events, total events saved are : 4760
#
# Working on Data_S24_Sess01.csv file ......
# Filtering signals with Bandpass IIR Filter!
# Slicing the data! We take 250 timepoints post feedback occurence to the user....
# The file contains 60 feedbacks!
# Recording the events, total events saved are : 4820
#
# Working on Data_S24_Sess02.csv file ......
# Filtering signals with Bandpass IIR Filter!
# Slicing the data! We take 250 timepoints post feedback occurence to the user....
# The file contains 60 feedbacks!
# Recording the events, total events saved are : 4880
#
# Working on Data_S24_Sess03.csv file ......
# Filtering signals with Bandpass IIR Filter!
# Slicing the data! We take 250 timepoints post feedback occurence to the user....
# The file contains 60 feedbacks!
# Recording the events, total events saved are : 4940
#
# Working on Data_S24_Sess04.csv file ......
# Filtering signals with Bandpass IIR Filter!
# Slicing the data! We take 250 timepoints post feedback occurence to the user....
# The file contains 60 feedbacks!
# Recording the events, total events saved are : 5000
#
# Working on Data_S24_Sess05.csv file ......
# Filtering signals with Bandpass IIR Filter!
# Slicing the data! We take 250 timepoints post feedback occurence to the user....
# The file contains 100 feedbacks!
# Recording the events, total events saved are : 5100
#
# Working on Data_S26_Sess01.csv file ......
# Filtering signals with Bandpass IIR Filter!
# Slicing the data! We take 250 timepoints post feedback occurence to the user....
# The file contains 60 feedbacks!
# Recording the events, total events saved are : 5160
#
# Working on Data_S26_Sess02.csv file ......
# Filtering signals with Bandpass IIR Filter!
# Slicing the data! We take 250 timepoints post feedback occurence to the user....
# The file contains 60 feedbacks!
# Recording the events, total events saved are : 5220
#
# Working on Data_S26_Sess03.csv file ......
# Filtering signals with Bandpass IIR Filter!
# Slicing the data! We take 250 timepoints post feedback occurence to the user....
# The file contains 60 feedbacks!
# Recording the events, total events saved are : 5280
#
# Working on Data_S26_Sess04.csv file ......
# Filtering signals with Bandpass IIR Filter!
# Slicing the data! We take 250 timepoints post feedback occurence to the user....
# The file contains 60 feedbacks!
# Recording the events, total events saved are : 5340
#
# Working on Data_S26_Sess05.csv file ......
# Filtering signals with Bandpass IIR Filter!
# Slicing the data! We take 250 timepoints post feedback occurence to the user....
# The file contains 100 feedbacks!
# Recording the events, total events saved are : 5440

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(24,16))


plt.plot(signals[:1000,1:57], label=columns_name)
plt.xlabel("Time")
plt.ylabel("Amplitude")
plt.title("Bandpass filtered data for 56 channels")
#plt.savefig("56filtered.png")
# Out:
# Text(0.5, 1.0, 'Bandpass filtered data for 56 channels')

# %%
sos = bandpass_design(1, 40, 200, order=4)
w, h = sosfreqz(sos, worN=2000)
plt.plot((200 * 0.5 / np.pi) * w, abs(h), label="order = 4")
plt.xlabel('Frequency (Hz)')
plt.ylabel('Gain')
plt.grid(True)
plt.legend(loc='best')
plt.title("Frequency Response of Butterworth Bandpass Filter")
#plt.savefig("Freqresp.png")
# Out:
# Text(0.5, 1.0, 'Frequency Response of Butterworth Bandpass Filter')

# %%
data_final = np.array(data_final)
data_final = data_final.reshape(5440,1,250,56)

print("Downsampling the data to 128 Hz ......")

for i in range(5440):
    for j in range(trials_sampled):
        downsampled_data_final[i,0,j,:] = data_final[i,0,int(j * 200 / 128),:]

print("After Downsampling, we get the size of data as: {} ".format(downsampled_data_final.shape))
#np.savetxt("Data_final.csv", np.reshape(downsampled_data_final,(5440*160,56)), delimiter=",")
print("Data saved to file as: Data_final.csv !")
# Out:
# Downsampling the data to 128 Hz ......
# After Downsampling, we get the size of data as: (5440, 1, 160, 56)
# Data saved to file as: Data_final.csv !

# %%
training_labels_file = pd.read_csv("TrainLabels.csv")

count_class_1, count_class_0 = training_labels_file.Prediction.value_counts()
labels_class0 = training_labels_file[training_labels_file['Prediction'] == 0]
labels_class1 = training_labels_file[training_labels_file['Prediction'] == 1]

class1_undersampled = labels_class1.sample(count_class_0) 
labels_balanced = pd.concat([class1_undersampled,labels_class0], axis = 0)
labels_balanced = labels_balanced.drop(['IdFeedBack'], axis=1).sort_index(0)

print(labels_balanced.Prediction.value_counts)
# labels_balanced = np.array(labels_balanced)
print(labels_balanced)
# Out:
# <bound method IndexOpsMixin.value_counts of 1       1
# 2       0
# 3       0
# 4       1
# 5       0
#        ..
# 5434    0
# 5436    0
# 5437    0
# 5438    0
# 5439    1
# Name: Prediction, Length: 3180, dtype: int64>
#       Prediction
# 1              1
# 2              0
# 3              0
# 4              1
# 5              0
# ...          ...
# 5434           0
# 5436           0
# 5437           0
# 5438           0
# 5439           1
#
# [3180 rows x 1 columns]

# %%
training_labels = training_labels_file.drop(['IdFeedBack'], axis =1)
training_labels = np.array(training_labels)
flattened_labels = training_labels[labels_balanced.index]

# def to_categorical(y, num_classes):
#     """ 1-hot encodes a tensor """
#     return np.eye(num_classes, dtype='float')[y]

def to_categorical(y, num_classes=None, dtype='int'):
    y = np.array(y, dtype='int')
    input_shape = y.shape
    if input_shape and input_shape[-1] == 1 and len(input_shape) > 1:
        input_shape = tuple(input_shape[:-1])
    y = y.ravel()
    if not num_classes:
        num_classes = np.max(y) + 1
    n = y.shape[0]
    categorical = np.zeros((n, num_classes), dtype=dtype)
    categorical[np.arange(n), y] = 1
    output_shape = input_shape + (num_classes,)
    categorical = np.reshape(categorical, output_shape)
    return categorical



#training_labels = to_categorical(training_labels,2)
training_labels = training_labels[labels_balanced.index,:]

# %%
reading_data_from_file = pd.read_csv("Data_final.csv")
trials_sampled = int(1.25*128)
print("Reading data from file!")
train_data_from_file = np.empty([len(labels_balanced),1,trials_sampled,56], dtype = 'float32')
print("Selecting data from balanced list according to labels ......")

# for index_3,trials in enumerate(labels_balanced.index):
#     train_data_from_file[index_3,0,:,:] = reading_data_from_file.iloc[trials *trials_sampled: (trials +1) * trials_sampled, :56]


downsampled_data_final = downsampled_data_final.reshape(5440*160,56)
for index_3,trials in enumerate(labels_balanced.index):
    train_data_from_file[index_3,0,:,:] = downsampled_data_final[trials *trials_sampled: (trials +1) * trials_sampled, :56]
# Out:
# Reading data from file!
# Selecting data from balanced list according to labels ......

# %%
print("The size of the balanced dataset is : {}".format(train_data_from_file.shape))
# Out:
# The size of the balanced dataset is : (3180, 1, 160, 56)

# %%
reading_test_data = np.genfromtxt(r"C:\Users\Admin\Adway\test_data\Data_final_test.csv", delimiter = ",")

trials_sampled = int(1.25*128)
print("Reading test data from file!")
test_data_from_file = np.empty([3400,1,trials_sampled,56], dtype = 'float32')
print("Selecting data from balanced list according to labels ......")

for index_4 in range(3400):
    test_data_from_file[index_4,0,:,:] = reading_test_data[index_4 *trials_sampled: (index_4 +1) * trials_sampled, :56]


print("The size of the test dataset is : {}".format(test_data_from_file.shape))
# Out:
# Reading test data from file!
# Selecting data from balanced list according to labels ......
# The size of the test dataset is : (3400, 1, 160, 56)

# %%
import numpy as np
from sklearn.metrics import roc_auc_score, precision_score, recall_score, accuracy_score
import torch
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable
import torch.nn.functional as F
import torch.optim as optim

# %%
class EEGNET_new(nn.Module):
    def __init__(self):
        super(EEGNET_new, self).__init__()
        
        self.T = 160

        # Block 1
        self.ConvLayer1 = nn.Conv2d(1,8,(1,56),bias= False, padding = 0)
        self.batchnormalization1 = nn.BatchNorm2d(8, False)
        self.depthwiseconvlayer1 = nn.Conv2d(8,8,(56,1), bias=False, groups=8)
        self.batchnormalization2 = nn.BatchNorm2d(8, False)
        self.averagepool1        = nn.AvgPool2d((1,1))

        # Block 2
        self.separableconvlayer_sub1 = nn.Conv2d(16,16,(1,8), bias= False, padding=4, groups=8)
        self.separableconvlayer_sub2 = nn.Conv2d(8,16,kernel_size=1)
        self.batchnormalization3     = nn.BatchNorm2d(16, False)
        self.averagepool2            = nn.AvgPool2d((1,2))
        
        # Block 3
        self.ConvLayer2 = nn.Conv2d(16,8,(8,1),bias= False, padding = 0)
        self.batchnormalization2 = nn.BatchNorm2d(8, False)
        self.depthwiseconvlayer2 = nn.Conv2d(8,8,(16,1), bias=False, groups=8)
        self.batchnormalization4 = nn.BatchNorm2d(8, False)
        self.averagepool3        = nn.AvgPool2d((1,1))
        
        self.fullyconnectedlayer = nn.Linear(4*2*91,1)


    def forward(self, x):
        x = F.elu(self.ConvLayer1(x))
        x = self.batchnormalization1(x)
        x = F.elu(self.depthwiseconvlayer1(x))
        x = self.batchnormalization2(x)
        #x = F.dropout(x,0.25)
        x = self.averagepool1(x)

        x = F.elu(self.separableconvlayer_sub1(self.separableconvlayer_sub2(x)))
        x = self.batchnormalization3(x)
        #x = F.dropout(x,0.25)
        x = self.averagepool2(x)
        
        x = F.elu(self.ConvLayer2(x))
        x = self.batchnormalization2(x)
        x = F.elu(self.depthwiseconvlayer2(x))
        x = self.batchnormalization4(x)
        x = F.dropout(x,0.25)
        x = self.averagepool3(x)
                
        x = x.view(-1, 4*2*91)
        x = torch.sigmoid(self.fullyconnectedlayer(x))   
        
        return x

net = EEGNET_new().cuda(0)
print(net.forward(Variable(torch.Tensor(np.random.rand(1, 1, 160, 56)).cuda(0))))
criterion = nn.BCELoss()
optimizer = optim.AdamW(net.parameters(), lr = 1e-2)
# Out:
# tensor([[0.4843]], device='cuda:0', grad_fn=<SigmoidBackward>)

# %%
cp_path = './CP5.pth'

# %%
from torchsummary import summary
summary(net,(1,160,56))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1            [-1, 8, 160, 1]             448
#        BatchNorm2d-2            [-1, 8, 160, 1]              16
#             Conv2d-3            [-1, 8, 105, 1]             448
#        BatchNorm2d-4            [-1, 8, 105, 1]              16
#          AvgPool2d-5            [-1, 8, 105, 1]               0
#             Conv2d-6           [-1, 16, 105, 1]             144
#             Conv2d-7           [-1, 16, 113, 2]             256
#        BatchNorm2d-8           [-1, 16, 113, 2]              32
#          AvgPool2d-9           [-1, 16, 113, 1]               0
#            Conv2d-10            [-1, 8, 106, 1]           1,024
#       BatchNorm2d-11            [-1, 8, 106, 1]              16
#            Conv2d-12             [-1, 8, 91, 1]             128
#       BatchNorm2d-13             [-1, 8, 91, 1]              16
#         AvgPool2d-14             [-1, 8, 91, 1]               0
#            Linear-15                    [-1, 1]             729
# ================================================================
# Total params: 3,273
# Trainable params: 3,273
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.03
# Forward/backward pass size (MB): 0.15
# Params size (MB): 0.01
# Estimated Total Size (MB): 0.20
# ----------------------------------------------------------------

# %%
def evaluate(model, X, Y, params = ["acc"]):
    results = []
    batch_size = 100
    
    predicted = []
    
    for i in range(int(len(X)/batch_size)):
        s = int(i*batch_size)
        e = int(i*batch_size+batch_size)
        
        inputs = Variable(torch.from_numpy(X[s:e]).cuda(0))
        pred = model(inputs)
        
        predicted.append(pred.data.cpu().numpy())
        
        
    inputs = Variable(torch.from_numpy(X).cuda(0))
    predicted = model(inputs)
    
    predicted = predicted.data.cpu().numpy() 
    
    #torch.save(model.state_dict(), cp_path)


    for param in params:
        if param == 'acc':
            results.append(accuracy_score(Y, np.round(predicted)))
        if param == "auc":
            results.append(roc_auc_score(Y, predicted))
        if param == "recall":
            results.append(recall_score(Y, np.round(predicted)))
        if param == "precision":
            results.append(precision_score(Y, np.round(predicted)))
        if param == "fmeasure":
            precision = precision_score(Y, np.round(predicted))
            recall = recall_score(Y, np.round(predicted))
            results.append(2*precision*recall/ (precision+recall))
    return results

# %%
X_train = train_data_from_file[:2544,:,:,:]
y_train = training_labels[:2544].astype('float32')

X_val = train_data_from_file[2544:,:,:,:]
y_val = training_labels[2544:].astype('float32')

X_test = test_data_from_file[:,:,:,:]
print(X_train.shape,y_train.shape,X_val.shape,y_val.shape,X_test.shape)
# Out:
# (2544, 1, 160, 56)(2544, 1)(636, 1, 160, 56)(636, 1)(3400, 1, 160, 56)

# %%
batch_size = 100
running_loss_array = []

for epoch in range(400):  # loop over the dataset multiple times
    print("\nEpoch ", epoch)
    
    running_loss = 0.0
    
    for i in range(int(len(X_train)/batch_size-1)):
        s = int(i*batch_size)
        e = int(i*batch_size+batch_size)
        
        inputs = torch.from_numpy(X_train[s:e])
        #labels = torch.FloatTensor(np.array([y_train[s:e]]).T*1.0)
        labels = torch.FloatTensor(y_train[s:e])
        
        # wrap them in Variable
        inputs, labels = Variable(inputs.cuda(0)), Variable(labels.cuda(0))

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = net(inputs)
        
        
        loss = criterion(outputs, labels)
        loss.backward()
        
        
        optimizer.step()
        
        running_loss += loss
        
        running_loss_array.append(running_loss)
        torch.save(net.state_dict(), cp_path)    
    
    
    # Validation accuracy
    params = ["acc", "auc", "fmeasure","precision", "recall"]
    print(params)
    print("Training Loss ", running_loss)
    print("Train - ", evaluate(net, X_train, y_train, params))
    
    
    
    

#     print "Test - ", evaluate(net, X_test, y_test, params)
# Out:
# Epoch0
# ['acc', 'auc', 'fmeasure', 'precision', 'recall']
# Training Losstensor(6.6489, device='cuda:0', grad_fn=<AddBackward0>)
# Train -[0.8018867924528302, 0.8840946640179138, 0.7967741935483872, 0.8576388888888888, 0.7439759036144579]
#
# Epoch1
# ['acc', 'auc', 'fmeasure', 'precision', 'recall']
# Training Losstensor(7.5961, device='cuda:0', grad_fn=<AddBackward0>)
# Train -[0.8238993710691824, 0.8942256484820863, 0.829657794676806, 0.8379416282642089, 0.8215361445783133]
#
# Epoch2
# ['acc', 'auc', 'fmeasure', 'precision', 'recall']
# Training Losstensor(6.4784, device='cuda:0', grad_fn=<AddBackward0>)
# Train -[0.8242924528301887, 0.9010519875554851, 0.8282750672301191, 0.8454901960784313, 0.8117469879518072]
#
# Epoch3
# ['acc', 'auc', 'fmeasure', 'precision', 'recall']
# Training Losstensor(5.2669, device='cuda:0', grad_fn=<AddBackward0>)
# Train -[0.8317610062893082, 0.9118263762285985, 0.8344934261407579, 0.8577106518282989, 0.8125]
#
# Epoch4
# ['acc', 'auc', 'fmeasure', 'precision', 'recall']
# Training Losstensor(5.3277, device='cuda:0', grad_fn=<AddBackward0>)
# Train -[0.8172169811320755, 0.8908302824785987, 0.816712652739456, 0.8569065343258891, 0.7801204819277109]
#
# Epoch5
# ['acc', 'auc', 'fmeasure', 'precision', 'recall']
# Training Losstensor(6.3527, device='cuda:0', grad_fn=<AddBackward0>)
# Train -[0.8199685534591195, 0.8987601309844643, 0.8299925760950259, 0.8184480234260615, 0.8418674698795181]
#
# Epoch6
# ['acc', 'auc', 'fmeasure', 'precision', 'recall']
# Training Losstensor(5.8691, device='cuda:0', grad_fn=<AddBackward0>)
# Train -[0.835691823899371, 0.9073281200459732, 0.8365910867865519, 0.8699186991869918, 0.8057228915662651]
#
# Epoch7
# ['acc', 'auc', 'fmeasure', 'precision', 'recall']
# Training Losstensor(5.5052, device='cuda:0', grad_fn=<AddBackward0>)
# Train -[0.8341194968553459, 0.9120641695069751, 0.8347689898198905, 0.8694942903752039, 0.802710843373494]
#
# Epoch8
# ['acc', 'auc', 'fmeasure', 'precision', 'recall']
# Training Losstensor(4.4534, device='cuda:0', grad_fn=<AddBackward0>)
# Train -[0.8408018867924528, 0.9156601735890932, 0.844887016468786, 0.8597038191738113, 0.8305722891566265]
#
# Epoch9
# ['acc', 'auc', 'fmeasure', 'precision', 'recall']
# Training Losstensor(4.8356, device='cuda:0', grad_fn=<AddBackward0>)
# Train -[0.8349056603773585, 0.9084938644380152, 0.8390804597701149, 0.8541341653666147, 0.8245481927710844]
#
# Epoch10
# ['acc', 'auc', 'fmeasure', 'precision', 'recall']
# Training Losstensor(6.0773, device='cuda:0', grad_fn=<AddBackward0>)
# Train -[0.8231132075471698, 0.8910900592501585, 0.8290273556231003, 0.8366564417177914, 0.8215361445783133]
#
# Epoch11
# ['acc', 'auc', 'fmeasure', 'precision', 'recall']
# Training Losstensor(6.8989, device='cuda:0', grad_fn=<AddBackward0>)
# Train -[0.8125, 0.8893660579819277, 0.8157589803012746, 0.8374306106264869, 0.7951807228915663]
#
# Epoch12
# ['acc', 'auc', 'fmeasure', 'precision', 'recall']
# Training Losstensor(5.4376, device='cuda:0', grad_fn=<AddBackward0>)
# Train -[0.827437106918239, 0.9076789270569119, 0.8310888803385917, 0.8497246262785209, 0.8132530120481928]
#
# Epoch13
# ['acc', 'auc', 'fmeasure', 'precision', 'recall']
# Training Losstensor(4.8031, device='cuda:0', grad_fn=<AddBackward0>)
# Train -[0.8541666666666666, 0.9231543773779328, 0.8596292092319333, 0.8638783269961977, 0.8554216867469879]
#
# Epoch14
# ['acc', 'auc', 'fmeasure', 'precision', 'recall']
# Training Losstensor(4.1740, device='cuda:0', grad_fn=<AddBackward0>)
# Train -[0.8380503144654088, 0.913241060458941, 0.8435839028094153, 0.8506891271056661, 0.8365963855421686]
#
# Epoch15
# ['acc', 'auc', 'fmeasure', 'precision', 'recall']
# Training Losstensor(4.1935, device='cuda:0', grad_fn=<AddBackward0>)
# Train -[0.8349056603773585, 0.9158413051878568, 0.8358092259577795, 0.8691056910569106, 0.8049698795180723]
#
# Epoch16
# ['acc', 'auc', 'fmeasure', 'precision', 'recall']
# Training Losstensor(4.4085, device='cuda:0', grad_fn=<AddBackward0>)
# Train -[0.8482704402515723, 0.9163896540107799, 0.853566009104704, 0.8600917431192661, 0.8471385542168675]
#
# Epoch17
# ['acc', 'auc', 'fmeasure', 'precision', 'recall']
# Training Losstensor(3.9042, device='cuda:0', grad_fn=<AddBackward0>)
# Train -[0.
device='cuda:0', grad_fn=<AddBackward0>)
# Train -[0.8714622641509434, 0.9428048336437858, 0.8740854832499036, 0.8944050433412135, 0.8546686746987951]
#
# Epoch390
# ['acc', 'auc', 'fmeasure', 'precision', 'recall']
# Training Losstensor(2.8801, device='cuda:0', grad_fn=<AddBackward0>)
# Train -[0.8671383647798742, 0.9320081518508243, 0.8724528301886794, 0.8744326777609682, 0.8704819277108434]
#
# Epoch391
# ['acc', 'auc', 'fmeasure', 'precision', 'recall']
# Training Losstensor(3.8032, device='cuda:0', grad_fn=<AddBackward0>)
# Train -[0.8584905660377359, 0.9394264971068486, 0.8608964451313756, 0.8841269841269841, 0.838855421686747]
#
# Epoch392
# ['acc', 'auc', 'fmeasure', 'precision', 'recall']
# Training Losstensor(3.3919, device='cuda:0', grad_fn=<AddBackward0>)
# Train -[0.8663522012578616, 0.9369773501902344, 0.8689282960678489, 0.8902053712480252, 0.848644578313253]
#
# Epoch393
# ['acc', 'auc', 'fmeasure', 'precision', 'recall']
# Training Losstensor(3.4111, device='cuda:0', grad_fn=<AddBackward0>)
# Train -[0.8714622641509434, 0.9362274344086874, 0.8758070641853399, 0.8835249042145594, 0.8682228915662651]
#
# Epoch394
# ['acc', 'auc', 'fmeasure', 'precision', 'recall']
# Training Losstensor(3.0503, device='cuda:0', grad_fn=<AddBackward0>)
# Train -[0.8651729559748428, 0.9397708019578315, 0.8688336520076482, 0.8826728826728827, 0.8554216867469879]
#
# Epoch395
# ['acc', 'auc', 'fmeasure', 'precision', 'recall']
# Training Losstensor(2.9441, device='cuda:0', grad_fn=<AddBackward0>)
# Train -[0.8691037735849056, 0.9331581052829739, 0.8752341701011614, 0.8709917971662938, 0.8795180722891566]
#
# Epoch396
# ['acc', 'auc', 'fmeasure', 'precision', 'recall']
# Training Losstensor(3.0672, device='cuda:0', grad_fn=<AddBackward0>)
# Train -[0.8781446540880503, 0.9457818940234622, 0.8802163833075733, 0.903968253968254, 0.8576807228915663]
#
# Epoch397
# ['acc', 'auc', 'fmeasure', 'precision', 'recall']
# Training Losstensor(2.4010, device='cuda:0', grad_fn=<AddBackward0>)
# Train -[0.8698899371069182, 0.9376071308259354, 0.8719535783365571, 0.8965791567223548, 0.848644578313253]
#
# Epoch398
# ['acc', 'auc', 'fmeasure', 'precision', 'recall']
# Training Losstensor(2.5652, device='cuda:0', grad_fn=<AddBackward0>)
# Train -[0.8714622641509434, 0.9333819653614459, 0.8752384586035865, 0.8870843000773395, 0.8637048192771084]
#
# Epoch399
# ['acc', 'auc', 'fmeasure', 'precision', 'recall']
# Training Losstensor(3.0399, device='cuda:0', grad_fn=<AddBackward0>)
# Train -[0.851808176100629, 0.926446018448795, 0.8571428571428571, 0.8627002288329519, 0.8516566265060241]

# %%
import matplotlib.pyplot as plt
from pylab import figure, axes, pie, title, show
plt.plot(running_loss_array)
plt.xlabel('Iterations')
plt.title('Loss function')
plt.ylabel('Loss')
#plt.savefig('Loss.png', dpi=200)
plt.show()

# %%
for param_tensor in net.state_dict():
    print(param_tensor, "\t", net.state_dict()[param_tensor].size())
# Out:
# ConvLayer1.weighttorch.Size([8, 1, 1, 56])
# batchnormalization1.weighttorch.Size([8])
# batchnormalization1.biastorch.Size([8])
# batchnormalization1.running_meantorch.Size([8])
# batchnormalization1.running_vartorch.Size([8])
# batchnormalization1.num_batches_trackedtorch.Size([])
# depthwiseconvlayer1.weighttorch.Size([8, 1, 56, 1])
# batchnormalization2.weighttorch.Size([8])
# batchnormalization2.biastorch.Size([8])
# batchnormalization2.running_meantorch.Size([8])
# batchnormalization2.running_vartorch.Size([8])
# batchnormalization2.num_batches_trackedtorch.Size([])
# separableconvlayer_sub1.weighttorch.Size([16, 2, 1, 8])
# separableconvlayer_sub2.weighttorch.Size([16, 8, 1, 1])
# separableconvlayer_sub2.biastorch.Size([16])
# batchnormalization3.weighttorch.Size([16])
# batchnormalization3.biastorch.Size([16])
# batchnormalization3.running_meantorch.Size([16])
# batchnormalization3.running_vartorch.Size([16])
# batchnormalization3.num_batches_trackedtorch.Size([])
# ConvLayer2.weighttorch.Size([8, 16, 8, 1])
# depthwiseconvlayer2.weighttorch.Size([8, 1, 16, 1])
# batchnormalization4.weighttorch.Size([8])
# batchnormalization4.biastorch.Size([8])
# batchnormalization4.running_meantorch.Size([8])
# batchnormalization4.running_vartorch.Size([8])
# batchnormalization4.num_batches_trackedtorch.Size([])
# fullyconnectedlayer.weighttorch.Size([1, 728])
# fullyconnectedlayer.biastorch.Size([1])

# %%
test_labels = pd.read_csv("true_labels.csv", header=None)
y_test = test_labels
print(y_test.shape)
# Out:
# (3400, 1)

# %%
train_copy = train_data_from_file
test_copy = test_data_from_file

print(train_copy.shape,test_copy.shape)
print(np.mean(train_copy[:,:,2,:]),"------",  np.std(train_copy[:,:,2,:]))
print(np.mean(test_copy[:,:,2,:]),"-----",  np.std(test_copy[:,:,2,:]))
diff = np.mean(train_copy[:,:,2,:]) - np.mean(test_copy[:,:,2,:])
print(diff)

normalized_test = np.empty_like(test_copy)
test_data_from_file2 = np.empty([1978,1,160,56], dtype = 'float32')
div_std = np.std(test_copy[:,:,2,:]) / np.std(train_copy[:,:,2,:])

for i in range(160):
    normalized_test[:,:,i,:] = test_copy[:,:,i,:] - .631483
    normalized_test[:,:,i,:] = normalized_test[:,:,i,:]/(div_std)

diff2 = np.mean(train_copy[:,:,2,:]) - np.mean(normalized_test[:,:,2,:])
print(np.mean(normalized_test[:,:,2,:]),"-----",  np.std(normalized_test[:,:,2,:]))
print(normalized_test.shape)
# Out:
# (3180, 1, 160, 56)(3400, 1, 160, 56)
# 0.86870944------10.824243
# 0.7536133-----18.687845
# 0.11509615
# 0.07073951-----10.824242
# (3400, 1, 160, 56)

# %%
net.load_state_dict(torch.load(cp_path))
net.eval()
batch_size = 100
with torch.no_grad():
    for i in range(int(len(normalized_test)/batch_size-1)):
        s = int(i*batch_size)
        e = int(i*batch_size+batch_size) 
        inputs_test_2 = torch.from_numpy(normalized_test[s:e])
    #         # wrap them in Variable
        inputs_test_2 = Variable(inputs_test_2.cuda(0))    

        predicted_test = []
        pred_test = net(inputs_test_2)

          
    # predicted_test.append(pred_test.data.cpu().numpy())


    inputs_test = torch.from_numpy(normalized_test)
            # wrap them in Variable
    inputs_test = Variable(inputs_test.cuda(0))    

    predicted_test = []
    pred_test = net(inputs_test)

        
    predicted_test.append(pred_test.data.cpu().numpy())

    
params = ["acc", "auc", "fmeasure","precision", "recall"]
print(params)                        
print("Validation - ", evaluate(net, X_val, y_val, params))
print("Test - ", evaluate(net, normalized_test, y_test, params))     
net = net.train()
# Out:
# ['acc', 'auc', 'fmeasure', 'precision', 'recall']
# Validation -[0.5047169811320755, 0.4975711311589175, 0.4741235392320534, 0.42136498516320475, 0.5419847328244275]
# Test -[0.5794117647058824, 0.5743430745248752, 0.6745562130177514, 0.7473524962178517, 0.6146827042720863]

# %%
#pred_test = pred_test.data.cpu().numpy()
final_submission = pd.read_csv("SampleSubmission.csv")
print(len(pred_test))
final_submission['Prediction'] = pred_test.data.cpu().numpy()
print(final_submission.head())
final_submission.to_csv("Results.csv", index = False, header = True)
# Out:
# 3400
#          IdFeedBack  Prediction
# 0  S01_Sess01_FB001    0.963153
# 1  S01_Sess01_FB002    0.517162
# 2  S01_Sess01_FB003    0.868895
# 3  S01_Sess01_FB004    0.597131
# 4  S01_Sess01_FB005    0.770572
